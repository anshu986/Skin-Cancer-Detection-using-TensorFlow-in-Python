# %%
import tensorflow as tf
import tensorflow_hub as hub
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from tensorflow.keras.utils import get_file
from sklearn.metrics import roc_curve, auc, confusion_matrix
from imblearn.metrics import sensitivity_score, specificity_score

import os
import glob
import zipfile
import random

# to get consistent results after multiple runs
tf.random.set_seed(7)
np.random.seed(7)
random.seed(7)

# 0 for benign, 1 for malignant
class_names = ["benign", "malignant"]

# %%
def download_and_extract_dataset():
  # dataset from https://github.com/udacity/dermatologist-ai
  # 5.3GB
  train_url = "https://s3-us-west-1.amazonaws.com/udacity-dlnfd/datasets/skin-cancer/train.zip"
  # 824.5MB
  valid_url = "https://s3-us-west-1.amazonaws.com/udacity-dlnfd/datasets/skin-cancer/valid.zip"
  # 5.1GB
  test_url  = "https://s3-us-west-1.amazonaws.com/udacity-dlnfd/datasets/skin-cancer/test.zip"
  for i, download_link in enumerate([valid_url, train_url, test_url]):
    temp_file = f"temp{i}.zip"
    data_dir = get_file(origin=download_link, fname=os.path.join(os.getcwd(), temp_file))
    print("Extracting", download_link)
    with zipfile.ZipFile(data_dir, "r") as z:
      z.extractall("data")
    # remove the temp file
    os.remove(temp_file)

# comment the below line if you already downloaded the dataset
download_and_extract_dataset()
# Out:
# Downloading data from https://s3-us-west-1.amazonaws.com/udacity-dlnfd/datasets/skin-cancer/valid.zip
# 864538487/864538487 [==============================] - 269s 0us/step
# Extracting https://s3-us-west-1.amazonaws.com/udacity-dlnfd/datasets/skin-cancer/valid.zip
# Downloading data from https://s3-us-west-1.amazonaws.com/udacity-dlnfd/datasets/skin-cancer/train.zip
# 5736557430/5736557430 [==============================] - 2134s 0us/step
# Extracting https://s3-us-west-1.amazonaws.com/udacity-dlnfd/datasets/skin-cancer/train.zip
# Downloading data from https://s3-us-west-1.amazonaws.com/udacity-dlnfd/datasets/skin-cancer/test.zip
# 5528640507/5528640507 [==============================] - 1670s 0us/step
# Extracting https://s3-us-west-1.amazonaws.com/udacity-dlnfd/datasets/skin-cancer/test.zip

# %%
# preparing data
# generate CSV metadata file to read img paths and labels from it
def generate_csv(folder, label2int):
    folder_name = os.path.basename(folder)
    labels = list(label2int)
    # generate CSV file
    df = pd.DataFrame(columns=["filepath", "label"])
    i = 0
    for label in labels:
        print("Reading", os.path.join(folder, label, "*"))
        for filepath in glob.glob(os.path.join(folder, label, "*")):
            df.loc[i] = [filepath, label2int[label]]
            i += 1
    output_file = f"{folder_name}.csv"
    print("Saving", output_file)
    df.to_csv(output_file)

# generate CSV files for all data portions, labeling nevus and seborrheic keratosis
# as 0 (benign), and melanoma as 1 (malignant)
# you should replace "data" path to your extracted dataset path
# don't replace if you used download_and_extract_dataset() function
generate_csv("data/train", {"nevus": 0, "seborrheic_keratosis": 0, "melanoma": 1})
generate_csv("data/valid", {"nevus": 0, "seborrheic_keratosis": 0, "melanoma": 1})
generate_csv("data/test", {"nevus": 0, "seborrheic_keratosis": 0, "melanoma": 1})
# Out:
# Reading data/train\nevus\*
# Reading data/train\seborrheic_keratosis\*
# Reading data/train\melanoma\*
# Saving train.csv
# Reading data/valid\nevus\*
# Reading data/valid\seborrheic_keratosis\*
# Reading data/valid\melanoma\*
# Saving valid.csv
# Reading data/test\nevus\*
# Reading data/test\seborrheic_keratosis\*
# Reading data/test\melanoma\*
# Saving test.csv

# %%
# loading data
train_metadata_filename = "train.csv"
valid_metadata_filename = "valid.csv"
# load CSV files as DataFrames
df_train = pd.read_csv(train_metadata_filename)
df_valid = pd.read_csv(valid_metadata_filename)
n_training_samples = len(df_train)
n_validation_samples = len(df_valid)
print("Number of training samples:", n_training_samples)
print("Number of validation samples:", n_validation_samples)
train_ds = tf.data.Dataset.from_tensor_slices((df_train["filepath"], df_train["label"]))
valid_ds = tf.data.Dataset.from_tensor_slices((df_valid["filepath"], df_valid["label"]))
# Out:
# Number of training samples: 2000
# Number of validation samples: 150

# %%
# preprocess data
def decode_img(img):
  # convert the compressed string to a 3D uint8 tensor
  img = tf.image.decode_jpeg(img, channels=3)
  # Use `convert_image_dtype` to convert to floats in the [0,1] range.
  img = tf.image.convert_image_dtype(img, tf.float32)
  # resize the image to the desired size.
  return tf.image.resize(img, [299, 299])


def process_path(filepath, label):
  # load the raw data from the file as a string
  img = tf.io.read_file(filepath)
  img = decode_img(img)
  return img, label


valid_ds = valid_ds.map(process_path)
train_ds = train_ds.map(process_path)
# test_ds = test_ds
for image, label in train_ds.take(1):
    print("Image shape:", image.shape)
    print("Label:", label.numpy())
# Out:
# Image shape: (299, 299, 3)
# Label: 0

# %%
# training parameters
batch_size = 64
optimizer = "rmsprop"

def prepare_for_training(ds, cache=True, batch_size=64, shuffle_buffer_size=1000):
  if cache:
    if isinstance(cache, str):
      ds = ds.cache(cache)
    else:
      ds = ds.cache()
  # shuffle the dataset
  ds = ds.shuffle(buffer_size=shuffle_buffer_size)
  # Repeat forever
  ds = ds.repeat()
  # split to batches
  ds = ds.batch(batch_size)
  # `prefetch` lets the dataset fetch batches in the background while the model
  # is training.
  ds = ds.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)
  return ds

valid_ds = prepare_for_training(valid_ds, batch_size=batch_size, cache="valid-cached-data")
train_ds = prepare_for_training(train_ds, batch_size=batch_size, cache="train-cached-data")

# %%
batch = next(iter(valid_ds))

def show_batch(batch):
  plt.figure(figsize=(12,12))
  for n in range(25):
      ax = plt.subplot(5,5,n+1)
      plt.imshow(batch[0][n])
      plt.title(class_names[batch[1][n].numpy()].title())
      plt.axis('off')
        
show_batch(batch)

# %%
# building the model
# InceptionV3 model & pre-trained weights
module_url = "https://tfhub.dev/google/tf2-preview/inception_v3/feature_vector/4"
m = tf.keras.Sequential([
    hub.KerasLayer(module_url, output_shape=[2048], trainable=False),
    tf.keras.layers.Dense(1, activation="sigmoid")
])

m.build([None, 299, 299, 3])
m.compile(loss="binary_crossentropy", optimizer=optimizer, metrics=["accuracy"])
m.summary()
# Out:
# WARNING:tensorflow:Please fix your imports. Module tensorflow.python.training.tracking.data_structures has been moved to tensorflow.python.trackable.data_structures. The old module will be deleted in version 2.11.
# WARNING:tensorflow:From C:\Users\anshu\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\tensorflow\python\autograph\pyct\static_analysis\liveness.py:83: Analyzer.lamba_check (from tensorflow.python.autograph.pyct.static_analysis.liveness) is deprecated and will be removed after 2023-09-23.
# Instructions for updating:
# Lambda fuctions will be no more assumed to be used in the statement where they are used, or at least in the same block. https://github.com/tensorflow/tensorflow/issues/56089
# WARNING:tensorflow:From C:\Users\anshu\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\tensorflow\python\autograph\pyct\static_analysis\liveness.py:83: Analyzer.lamba_check (from tensorflow.python.autograph.pyct.static_analysis.liveness) is deprecated and will be removed after 2023-09-23.
# Instructions for updating:
# Lambda fuctions will be no more assumed to be used in the statement where they are used, or at least in the same block. https://github.com/tensorflow/tensorflow/issues/56089
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  keras_layer (KerasLayer)    (None, 2048)              21802784
#
#  dense (Dense)               (None, 1)                 2049
#
# =================================================================
# Total params: 21,804,833
# Trainable params: 2,049
# Non-trainable params: 21,802,784
# _________________________________________________________________

# %%
model_name = f"benign-vs-malignant_{batch_size}_{optimizer}"
tensorboard = tf.keras.callbacks.TensorBoard(log_dir=os.path.join("logs", model_name))
# saves model checkpoint whenever we reach better weights
modelcheckpoint = tf.keras.callbacks.ModelCheckpoint(model_name + "_{val_loss:.3f}.h5", save_best_only=True, verbose=1)

history = m.fit(train_ds, validation_data=valid_ds, 
                steps_per_epoch=n_training_samples // batch_size, 
                validation_steps=n_validation_samples // batch_size, verbose=1, epochs=100,
                callbacks=[tensorboard, modelcheckpoint])
# Out:
# Epoch 1/100
# 31/31 [==============================] - ETA: 0s - loss: 0.4120 - accuracy: 0.8034
# Epoch 1: val_loss improved from inf to 0.50471, saving model to benign-vs-malignant_64_rmsprop_0.505.h5
# 31/31 [==============================] - 159s 4s/step - loss: 0.4120 - accuracy: 0.8034 - val_loss: 0.5047 - val_accuracy: 0.7969
# Epoch 2/100
# 31/31 [==============================] - ETA: 0s - loss: 0.3927 - accuracy: 0.8095
# Epoch 2: val_loss improved from 0.50471 to 0.46281, saving model to benign-vs-malignant_64_rmsprop_0.463.h5
# 31/31 [==============================] - 88s 3s/step - loss: 0.3927 - accuracy: 0.8095 - val_loss: 0.4628 - val_accuracy: 0.8125
# Epoch 3/100
# 31/31 [==============================] - ETA: 0s - loss: 0.3768 - accuracy: 0.8175
# Epoch 3: val_loss did not improve from 0.46281
# 31/31 [==============================] - 87s 3s/step - loss: 0.3768 - accuracy: 0.8175 - val_loss: 0.4653 - val_accuracy: 0.7969
# Epoch 4/100
# 31/31 [==============================] - ETA: 0s - loss: 0.3670 - accuracy: 0.8251
# Epoch 4: val_loss did not improve from 0.46281
# 31/31 [==============================] - 126s 4s/step - loss: 0.3670 - accuracy: 0.8251 - val_loss: 0.4820 - val_accuracy: 0.7812
# Epoch 5/100
# 31/31 [==============================] - ETA: 0s - loss: 0.3505 - accuracy: 0.8407
# Epoch 5: val_loss improved from 0.46281 to 0.44077, saving model to benign-vs-malignant_64_rmsprop_0.441.h5
# 31/31 [==============================] - 95s 3s/step - loss: 0.3505 - accuracy: 0.8407 - val_loss: 0.4408 - val_accuracy: 0.7969
# Epoch 6/100
# 31/31 [==============================] - ETA: 0s - loss: 0.3463 - accuracy: 0.8422
# Epoch 6: val_loss did not improve from 0.44077
# 31/31 [==============================] - 88s 3s/step - loss: 0.3463 - accuracy: 0.8422 - val_loss: 0.4509 - val_accuracy: 0.8047
# Epoch 7/100
# 31/31 [==============================] - ETA: 0s - loss: 0.3438 - accuracy: 0.8417
# Epoch 7: val_loss did not improve from 0.44077
# 31/31 [==============================] - 102s 3s/step - loss: 0.3438 - accuracy: 0.8417 - val_loss: 0.4446 - val_accuracy: 0.7891
# Epoch 8/100
# 31/31 [==============================] - ETA: 0s - loss: 0.3348 - accuracy: 0.8412
# Epoch 8: val_loss improved from 0.44077 to 0.42571, saving model to benign-vs-malignant_64_rmsprop_0.426.h5
# 31/31 [==============================] - 123s 4s/step - loss: 0.3348 - accuracy: 0.8412 - val_loss: 0.4257 - val_accuracy: 0.8047
# Epoch 9/100
# 31/31 [==============================] - ETA: 0s - loss: 0.3463 - accuracy: 0.8427
# Epoch 9: val_loss did not improve from 0.42571
# 31/31 [==============================] - 122s 4s/step - loss: 0.3463 - accuracy: 0.8427 - val_loss: 0.4457 - val_accuracy: 0.7969
# Epoch 10/100
# 31/31 [==============================] - ETA: 0s - loss: 0.3125 - accuracy: 0.8614
# Epoch 10: val_loss did not improve from 0.42571
# 31/31 [==============================] - 122s 4s/step - loss: 0.3125 - accuracy: 0.8614 - val_loss: 0.5084 - val_accuracy: 0.7188
# Epoch 11/100
# 31/31 [==============================] - ETA: 0s - loss: 0.3123 - accuracy: 0.8634
# Epoch 11: val_loss did not improve from 0.42571
# 31/31 [==============================] - 122s 4s/step - loss: 0.3123 - accuracy: 0.8634 - val_loss: 0.4537 - val_accuracy: 0.7891
# Epoch 12/100
# 31/31 [==============================] - ETA: 0s - loss: 0.3280 - accuracy: 0.8564
# Epoch 12: val_loss did not improve from 0.42571
# 31/31 [==============================] - 123s 4s/step - loss: 0.3280 - accuracy: 0.8564 - val_loss: 0.4422 - val_accuracy: 0.8047
# Epoch 13/100
# 31/31 [==============================] - ETA: 0s - loss: 0.3339 - accuracy: 0.8438
# Epoch 13: val_loss did not improve from 0.42571
# 31/31 [==============================] - 128s 4s/step - loss: 0.3339 - accuracy: 0.8438 - val_loss: 0.4495 - val_accuracy: 0.8047
# Epoch 14/100
# 31/31 [==============================] - ETA: 0s - loss: 0.3075 - accuracy: 0.8634
# Epoch 14: val_loss did not improve from 0.42571
# 31/31 [==============================] - 122s 4s/step - loss: 0.3075 - accuracy: 0.8634 - val_loss: 0.5105 - val_accuracy: 0.7422
# Epoch 15/100
# 31/31 [==============================] - ETA: 0s - loss: 0.3138 - accuracy: 0.8599
# Epoch 15: val_loss did not improve from 0.42571
# 31/31 [==============================] - 122s 4s/step - loss: 0.3138 - accuracy: 0.8599 - val_loss: 0.4497 - val_accuracy: 0.8047
# Epoch 16/100
# 31/31 [==============================] - ETA: 0s - loss: 0.3190 - accuracy: 0.8574
# Epoch 16: val_loss did not improve from 0.42571
# 31/31 [==============================] - 121s 4s/step - loss: 0.3190 - accuracy: 0.8574 - val_loss: 0.4558 - val_accuracy: 0.7891
# Epoch 17/100
# 31/31 [==============================] - ETA: 0s - loss: 0.3188 - accuracy: 0.8548
# Epoch 17: val_loss did not improve from 0.42571
# 31/31 [==============================] - 150s 5s/step - loss: 0.3188 - accuracy: 0.8548 - val_loss: 0.4892 - val_accuracy: 0.7656
# Epoch 18/100
# 31/31 [==============================] - ETA: 0s - loss: 0.3038 - accuracy: 0.8684
# Epoch 18: val_loss did not improve from 0.42571
# 31/31 [==============================] - 122s 4s/step - loss: 0.3038 - accuracy: 0.8684 - val_loss: 0.5095 - val_accuracy: 0.7266
# Epoch 19/100
# 31/31 [==============================] - ETA: 0s - loss: 0.3118 - accuracy: 0.8634
# Epoch 19: val_loss improved from 0.42571 to 0.42347, saving model to benign-vs-malignant_64_rmsprop_0.423.h5
# 31/31 [==============================] - 122s 4s/step - loss: 0.3118 - accuracy: 0.8634 - val_loss: 0.4235 - val_accuracy: 0.7969
# Epoch 20/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2917 - accuracy: 0.8700
# Epoch 20: val_loss did not improve from 0.42347
# 31/31 [==============================] - 130s 4s/step - loss: 0.2917 - accuracy: 0.8700 - val_loss: 0.4589 - val_accuracy: 0.7891
# Epoch 21/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2985 - accuracy: 0.8684
# Epoch 21: val_loss improved from 0.42347 to 0.40867, saving model to benign-vs-malignant_64_rmsprop_0.409.h5
# 31/31 [==============================] - 139s 5s/step - loss: 0.2985 - accuracy: 0.8684 - val_loss: 0.4087 - val_accuracy: 0.8047
# Epoch 22/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2984 - accuracy: 0.8720
# Epoch 22: val_loss did not improve from 0.40867
# 31/31 [==============================] - 137s 4s/step - loss: 0.2984 - accuracy: 0.8720 - val_loss: 0.4600 - val_accuracy: 0.7734
# Epoch 23/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2937 - accuracy: 0.8720
# Epoch 23: val_loss did not improve from 0.40867
# 31/31 [==============================] - 138s 4s/step - loss: 0.2937 - accuracy: 0.8720 - val_loss: 0.4622 - val_accuracy: 0.7969
# Epoch 24/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2888 - accuracy: 0.8679
# Epoch 24: val_loss did not improve from 0.40867
# 31/31 [==============================] - 142s 5s/step - loss: 0.2888 - accuracy: 0.8679 - val_loss: 0.4716 - val_accuracy: 0.7812
# Epoch 25/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2905 - accuracy: 0.8816
# Epoch 25: val_loss did not improve from 0.40867
# 31/31 [==============================] - 140s 5s/step - loss: 0.2905 - accuracy: 0.8816 - val_loss: 0.4595 - val_accuracy: 0.8047
# Epoch 26/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2991 - accuracy: 0.8720
# Epoch 26: val_loss did not improve from 0.40867
# 31/31 [==============================] - 146s 5s/step - loss: 0.2991 - accuracy: 0.8720 - val_loss: 0.4566 - val_accuracy: 0.8047
# Epoch 27/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2854 - accuracy: 0.8730
# Epoch 27: val_loss did not improve from 0.40867
# 31/31 [==============================] - 141s 5s/step - loss: 0.2854 - accuracy: 0.8730 - val_loss: 0.4344 - val_accuracy: 0.8047
# Epoch 28/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2749 - accuracy: 0.8836
# Epoch 28: val_loss did not improve from 0.40867
# 31/31 [==============================] - 123s 4s/step - loss: 0.2749 - accuracy: 0.8836 - val_loss: 0.4449 - val_accuracy: 0.8359
# Epoch 29/100
# 31/31 [==============================] - ETA: 0s - loss: 0.3025 - accuracy: 0.8594
# Epoch 29: val_loss did not improve from 0.40867
# 31/31 [==============================] - 123s 4s/step - loss: 0.3025 - accuracy: 0.8594 - val_loss: 0.4437 - val_accuracy: 0.8438
# Epoch 30/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2792 - accuracy: 0.8775
# Epoch 30: val_loss did not improve from 0.40867
# 31/31 [==============================] - 122s 4s/step - loss: 0.2792 - accuracy: 0.8775 - val_loss: 0.4350 - val_accuracy: 0.8125
# Epoch 31/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2785 - accuracy: 0.8800
# Epoch 31: val_loss did not improve from 0.40867
# 31/31 [==============================] - 122s 4s/step - loss: 0.2785 - accuracy: 0.8800 - val_loss: 0.4517 - val_accuracy: 0.8125
# Epoch 32/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2823 - accuracy: 0.8826
# Epoch 32: val_loss improved from 0.40867 to 0.37320, saving model to benign-vs-malignant_64_rmsprop_0.373.h5
# 31/31 [==============================] - 123s 4s/step - loss: 0.2823 - accuracy: 0.8826 - val_loss: 0.3732 - val_accuracy: 0.8359
# Epoch 33/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2637 - accuracy: 0.8886
# Epoch 33: val_loss did not improve from 0.37320
# 31/31 [==============================] - 124s 4s/step - loss: 0.2637 - accuracy: 0.8886 - val_loss: 0.4172 - val_accuracy: 0.8125
# Epoch 34/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2752 - accuracy: 0.8795
# Epoch 34: val_loss did not improve from 0.37320
# 31/31 [==============================] - 143s 5s/step - loss: 0.2752 - accuracy: 0.8795 - val_loss: 0.4837 - val_accuracy: 0.7656
# Epoch 35/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2812 - accuracy: 0.8745
# Epoch 35: val_loss did not improve from 0.37320
# 31/31 [==============================] - 134s 4s/step - loss: 0.2812 - accuracy: 0.8745 - val_loss: 0.4296 - val_accuracy: 0.8047
# Epoch 36/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2736 - accuracy: 0.8836
# Epoch 36: val_loss did not improve from 0.37320
# 31/31 [==============================] - 137s 4s/step - loss: 0.2736 - accuracy: 0.8836 - val_loss: 0.4197 - val_accuracy: 0.8281
# Epoch 37/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2791 - accuracy: 0.8790
# Epoch 37: val_loss did not improve from 0.37320
# 31/31 [==============================] - 137s 4s/step - loss: 0.2791 - accuracy: 0.8790 - val_loss: 0.4616 - val_accuracy: 0.8125
# Epoch 38/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2815 - accuracy: 0.8805
# Epoch 38: val_loss did not improve from 0.37320
# 31/31 [==============================] - 130s 4s/step - loss: 0.2815 - accuracy: 0.8805 - val_loss: 0.4915 - val_accuracy: 0.7422
# Epoch 39/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2617 - accuracy: 0.8841
# Epoch 39: val_loss did not improve from 0.37320
# 31/31 [==============================] - 125s 4s/step - loss: 0.2617 - accuracy: 0.8841 - val_loss: 0.4367 - val_accuracy: 0.8047
# Epoch 40/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2632 - accuracy: 0.8997
# Epoch 40: val_loss did not improve from 0.37320
# 31/31 [==============================] - 126s 4s/step - loss: 0.2632 - accuracy: 0.8997 - val_loss: 0.4154 - val_accuracy: 0.8281
# Epoch 41/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2778 - accuracy: 0.8856
# Epoch 41: val_loss did not improve from 0.37320
# 31/31 [==============================] - 134s 4s/step - loss: 0.2778 - accuracy: 0.8856 - val_loss: 0.4824 - val_accuracy: 0.7969
# Epoch 42/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2716 - accuracy: 0.8836
# Epoch 42: val_loss did not improve from 0.37320
# 31/31 [==============================] - 124s 4s/step - loss: 0.2716 - accuracy: 0.8836 - val_loss: 0.4408 - val_accuracy: 0.8125
# Epoch 43/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2733 - accuracy: 0.8871
# Epoch 43: val_loss did not improve from 0.37320
# 31/31 [==============================] - 124s 4s/step - loss: 0.2733 - accuracy: 0.8871 - val_loss: 0.5153 - val_accuracy: 0.7734
# Epoch 44/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2647 - accuracy: 0.8891
# Epoch 44: val_loss did not improve from 0.37320
# 31/31 [==============================] - 127s 4s/step - loss: 0.2647 - accuracy: 0.8891 - val_loss: 0.4470 - val_accuracy: 0.8281
# Epoch 45/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2729 - accuracy: 0.8810
# Epoch 45: val_loss did not improve from 0.37320
# 31/31 [==============================] - 130s 4s/step - loss: 0.2729 - accuracy: 0.8810 - val_loss: 0.4559 - val_accuracy: 0.8047
# Epoch 46/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2471 - accuracy: 0.8987
# Epoch 46: val_loss did not improve from 0.37320
# 31/31 [==============================] - 134s 4s/step - loss: 0.2471 - accuracy: 0.8987 - val_loss: 0.4644 - val_accuracy: 0.8047
# Epoch 47/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2748 - accuracy: 0.8795
# Epoch 47: val_loss did not improve from 0.37320
# 31/31 [==============================] - 139s 4s/step - loss: 0.2748 - accuracy: 0.8795 - val_loss: 0.4696 - val_accuracy: 0.8047
# Epoch 48/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2621 - accuracy: 0.8906
# Epoch 48: val_loss did not improve from 0.37320
# 31/31 [==============================] - 140s 5s/step - loss: 0.2621 - accuracy: 0.8906 - val_loss: 0.4575 - val_accuracy: 0.7969
# Epoch 49/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2648 - accuracy: 0.8841
# Epoch 49: val_loss did not improve from 0.37320
# 31/31 [==============================] - 143s 5s/step - loss: 0.2648 - accuracy: 0.8841 - val_loss: 0.4845 - val_accuracy: 0.7969
# Epoch 50/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2482 - accuracy: 0.8957
# Epoch 50: val_loss did not improve from 0.37320
# 31/31 [==============================] - 146s 5s/step - loss: 0.2482 - accuracy: 0.8957 - val_loss: 0.4349 - val_accuracy: 0.8125
# Epoch 51/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2574 - accuracy: 0.8931
# Epoch 51: val_loss did not improve from 0.37320
# 31/31 [==============================] - 140s 5s/step - loss: 0.2574 - accuracy: 0.8931 - val_loss: 0.4218 - val_accuracy: 0.8203
# Epoch 52/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2521 - accuracy: 0.9052
# Epoch 52: val_loss did not improve from 0.37320
# 31/31 [==============================] - 138s 4s/step - loss: 0.2521 - accuracy: 0.9052 - val_loss: 0.4370 - val_accuracy: 0.8281
# Epoch 53/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2549 - accuracy: 0.8947
# Epoch 53: val_loss did not improve from 0.37320
# 31/31 [==============================] - 131s 4s/step - loss: 0.2549 - accuracy: 0.8947 - val_loss: 0.4494 - val_accuracy: 0.8125
# Epoch 54/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2624 - accuracy: 0.8876
# Epoch 54: val_loss did not improve from 0.37320
# 31/31 [==============================] - 127s 4s/step - loss: 0.2624 - accuracy: 0.8876 - val_loss: 0.4791 - val_accuracy: 0.7969
# Epoch 55/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2551 - accuracy: 0.8947
# Epoch 55: val_loss did not improve from 0.37320
# 31/31 [==============================] - 95s 3s/step - loss: 0.2551 - accuracy: 0.8947 - val_loss: 0.4869 - val_accuracy: 0.8047
# Epoch 56/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2450 - accuracy: 0.8992
# Epoch 56: val_loss did not improve from 0.37320
# 31/31 [==============================] - 82s 3s/step - loss: 0.2450 - accuracy: 0.8992 - val_loss: 0.4261 - val_accuracy: 0.8203
# Epoch 57/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2451 - accuracy: 0.8957
# Epoch 57: val_loss did not improve from 0.37320
# 31/31 [==============================] - 84s 3s/step - loss: 0.2451 - accuracy: 0.8957 - val_loss: 0.4790 - val_accuracy: 0.8047
# Epoch 58/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2442 - accuracy: 0.9002
# Epoch 58: val_loss did not improve from 0.37320
# 31/31 [==============================] - 89s 3s/step - loss: 0.2442 - accuracy: 0.9002 - val_loss: 0.3976 - val_accuracy: 0.8359
# Epoch 59/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2454 - accuracy: 0.8987
# Epoch 59: val_loss did not improve from 0.37320
# 31/31 [==============================] - 90s 3s/step - loss: 0.2454 - accuracy: 0.8987 - val_loss: 0.4958 - val_accuracy: 0.7969
# Epoch 60/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2495 - accuracy: 0.8906
# Epoch 60: val_loss did not improve from 0.37320
# 31/31 [==============================] - 88s 3s/step - loss: 0.2495 - accuracy: 0.8906 - val_loss: 0.4740 - val_accuracy: 0.7812
# Epoch 61/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2607 - accuracy: 0.8942
# Epoch 61: val_loss did not improve from 0.37320
# 31/31 [==============================] - 90s 3s/step - loss: 0.2607 - accuracy: 0.8942 - val_loss: 0.4521 - val_accuracy: 0.7500
# Epoch 62/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2478 - accuracy: 0.8977
# Epoch 62: val_loss did not improve from 0.37320
# 31/31 [==============================] - 90s 3s/step - loss: 0.2478 - accuracy: 0.8977 - val_loss: 0.4888 - val_accuracy: 0.7891
# Epoch 63/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2571 - accuracy: 0.8921
# Epoch 63: val_loss did not improve from 0.37320
# 31/31 [==============================] - 90s 3s/step - loss: 0.2571 - accuracy: 0.8921 - val_loss: 0.4515 - val_accuracy: 0.8203
# Epoch 64/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2367 - accuracy: 0.9042
# Epoch 64: val_loss did not improve from 0.37320
# 31/31 [==============================] - 91s 3s/step - loss: 0.2367 - accuracy: 0.9042 - val_loss: 0.4997 - val_accuracy: 0.7891
# Epoch 65/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2525 - accuracy: 0.8921
# Epoch 65: val_loss did not improve from 0.37320
# 31/31 [==============================] - 91s 3s/step - loss: 0.2525 - accuracy: 0.8921 - val_loss: 0.4588 - val_accuracy: 0.8125
# Epoch 66/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2266 - accuracy: 0.9098
# Epoch 66: val_loss did not improve from 0.37320
# 31/31 [==============================] - 91s 3s/step - loss: 0.2266 - accuracy: 0.9098 - val_loss: 0.4635 - val_accuracy: 0.8281
# Epoch 67/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2329 - accuracy: 0.9052
# Epoch 67: val_loss did not improve from 0.37320
# 31/31 [==============================] - 91s 3s/step - loss: 0.2329 - accuracy: 0.9052 - val_loss: 0.4954 - val_accuracy: 0.8047
# Epoch 68/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2504 - accuracy: 0.8987
# Epoch 68: val_loss did not improve from 0.37320
# 31/31 [==============================] - 93s 3s/step - loss: 0.2504 - accuracy: 0.8987 - val_loss: 0.4592 - val_accuracy: 0.7969
# Epoch 69/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2368 - accuracy: 0.9078
# Epoch 69: val_loss did not improve from 0.37320
# 31/31 [==============================] - 92s 3s/step - loss: 0.2368 - accuracy: 0.9078 - val_loss: 0.4248 - val_accuracy: 0.8203
# Epoch 70/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2457 - accuracy: 0.8957
# Epoch 70: val_loss did not improve from 0.37320
# 31/31 [==============================] - 84s 3s/step - loss: 0.2457 - accuracy: 0.8957 - val_loss: 0.4677 - val_accuracy: 0.7969
# Epoch 71/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2337 - accuracy: 0.9062
# Epoch 71: val_loss did not improve from 0.37320
# 31/31 [==============================] - 87s 3s/step - loss: 0.2337 - accuracy: 0.9062 - val_loss: 0.4775 - val_accuracy: 0.8438
# Epoch 72/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2444 - accuracy: 0.8987
# Epoch 72: val_loss did not improve from 0.37320
# 31/31 [==============================] - 87s 3s/step - loss: 0.2444 - accuracy: 0.8987 - val_loss: 0.5086 - val_accuracy: 0.8203
# Epoch 73/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2429 - accuracy: 0.8962
# Epoch 73: val_loss did not improve from 0.37320
# 31/31 [==============================] - 87s 3s/step - loss: 0.2429 - accuracy: 0.8962 - val_loss: 0.6705 - val_accuracy: 0.8047
# Epoch 74/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2399 - accuracy: 0.9093
# Epoch 74: val_loss did not improve from 0.37320
# 31/31 [==============================] - 88s 3s/step - loss: 0.2399 - accuracy: 0.9093 - val_loss: 0.4796 - val_accuracy: 0.8516
# Epoch 75/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2248 - accuracy: 0.9078
# Epoch 75: val_loss did not improve from 0.37320
# 31/31 [==============================] - 85s 3s/step - loss: 0.2248 - accuracy: 0.9078 - val_loss: 0.5999 - val_accuracy: 0.8203
# Epoch 76/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2360 - accuracy: 0.9022
# Epoch 76: val_loss did not improve from 0.37320
# 31/31 [==============================] - 91s 3s/step - loss: 0.2360 - accuracy: 0.9022 - val_loss: 0.7611 - val_accuracy: 0.7812
# Epoch 77/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2447 - accuracy: 0.8992
# Epoch 77: val_loss did not improve from 0.37320
# 31/31 [==============================] - 87s 3s/step - loss: 0.2447 - accuracy: 0.8992 - val_loss: 0.6780 - val_accuracy: 0.7969
# Epoch 78/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2275 - accuracy: 0.9002
# Epoch 78: val_loss did not improve from 0.37320
# 31/31 [==============================] - 85s 3s/step - loss: 0.2275 - accuracy: 0.9002 - val_loss: 0.7153 - val_accuracy: 0.7969
# Epoch 79/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2255 - accuracy: 0.9098
# Epoch 79: val_loss did not improve from 0.37320
# 31/31 [==============================] - 87s 3s/step - loss: 0.2255 - accuracy: 0.9098 - val_loss: 0.8485 - val_accuracy: 0.7812
# Epoch 80/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2276 - accuracy: 0.9052
# Epoch 80: val_loss did not improve from 0.37320
# 31/31 [==============================] - 93s 3s/step - loss: 0.2276 - accuracy: 0.9052 - val_loss: 0.8838 - val_accuracy: 0.7891
# Epoch 81/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2385 - accuracy: 0.9002
# Epoch 81: val_loss did not improve from 0.37320
# 31/31 [==============================] - 93s 3s/step - loss: 0.2385 - accuracy: 0.9002 - val_loss: 0.8247 - val_accuracy: 0.7969
# Epoch 82/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2253 - accuracy: 0.9128
# Epoch 82: val_loss did not improve from 0.37320
# 31/31 [==============================] - 98s 3s/step - loss: 0.2253 - accuracy: 0.9128 - val_loss: 0.8408 - val_accuracy: 0.7969
# Epoch 83/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2355 - accuracy: 0.9057
# Epoch 83: val_loss did not improve from 0.37320
# 31/31 [==============================] - 95s 3s/step - loss: 0.2355 - accuracy: 0.9057 - val_loss: 0.9075 - val_accuracy: 0.8047
# Epoch 84/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2359 - accuracy: 0.9052
# Epoch 84: val_loss did not improve from 0.37320
# 31/31 [==============================] - 95s 3s/step - loss: 0.2359 - accuracy: 0.9052 - val_loss: 0.8844 - val_accuracy: 0.7969
# Epoch 85/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2359 - accuracy: 0.8997
# Epoch 85: val_loss did not improve from 0.37320
# 31/31 [==============================] - 94s 3s/step - loss: 0.2359 - accuracy: 0.8997 - val_loss: 0.8116 - val_accuracy: 0.8125
# Epoch 86/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2272 - accuracy: 0.9093
# Epoch 86: val_loss did not improve from 0.37320
# 31/31 [==============================] - 94s 3s/step - loss: 0.2272 - accuracy: 0.9093 - val_loss: 0.9643 - val_accuracy: 0.7891
# Epoch 87/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2280 - accuracy: 0.9062
# Epoch 87: val_loss did not improve from 0.37320
# 31/31 [==============================] - 92s 3s/step - loss: 0.2280 - accuracy: 0.9062 - val_loss: 0.8557 - val_accuracy: 0.8047
# Epoch 88/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2241 - accuracy: 0.9143
# Epoch 88: val_loss did not improve from 0.37320
# 31/31 [==============================] - 92s 3s/step - loss: 0.2241 - accuracy: 0.9143 - val_loss: 0.9723 - val_accuracy: 0.7812
# Epoch 89/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2372 - accuracy: 0.9108
# Epoch 89: val_loss did not improve from 0.37320
# 31/31 [==============================] - 92s 3s/step - loss: 0.2372 - accuracy: 0.9108 - val_loss: 0.8231 - val_accuracy: 0.8125
# Epoch 90/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2286 - accuracy: 0.9037
# Epoch 90: val_loss did not improve from 0.37320
# 31/31 [==============================] - 94s 3s/step - loss: 0.2286 - accuracy: 0.9037 - val_loss: 0.7627 - val_accuracy: 0.8125
# Epoch 91/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2291 - accuracy: 0.9118
# Epoch 91: val_loss did not improve from 0.37320
# 31/31 [==============================] - 92s 3s/step - loss: 0.2291 - accuracy: 0.9118 - val_loss: 0.8510 - val_accuracy: 0.8125
# Epoch 92/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2290 - accuracy: 0.9042
# Epoch 92: val_loss did not improve from 0.37320
# 31/31 [==============================] - 92s 3s/step - loss: 0.2290 - accuracy: 0.9042 - val_loss: 0.8953 - val_accuracy: 0.7969
# Epoch 93/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2415 - accuracy: 0.9002
# Epoch 93: val_loss did not improve from 0.37320
# 31/31 [==============================] - 93s 3s/step - loss: 0.2415 - accuracy: 0.9002 - val_loss: 0.8111 - val_accuracy: 0.7969
# Epoch 94/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2219 - accuracy: 0.9088
# Epoch 94: val_loss did not improve from 0.37320
# 31/31 [==============================] - 88s 3s/step - loss: 0.2219 - accuracy: 0.9088 - val_loss: 0.8474 - val_accuracy: 0.8047
# Epoch 95/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2296 - accuracy: 0.9057
# Epoch 95: val_loss did not improve from 0.37320
# 31/31 [==============================] - 85s 3s/step - loss: 0.2296 - accuracy: 0.9057 - val_loss: 0.7614 - val_accuracy: 0.8203
# Epoch 96/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2245 - accuracy: 0.9088
# Epoch 96: val_loss did not improve from 0.37320
# 31/31 [==============================] - 83s 3s/step - loss: 0.2245 - accuracy: 0.9088 - val_loss: 0.7914 - val_accuracy: 0.8047
# Epoch 97/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2260 - accuracy: 0.9133
# Epoch 97: val_loss did not improve from 0.37320
# 31/31 [==============================] - 82s 3s/step - loss: 0.2260 - accuracy: 0.9133 - val_loss: 0.7716 - val_accuracy: 0.8125
# Epoch 98/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2152 - accuracy: 0.9123
# Epoch 98: val_loss did not improve from 0.37320
# 31/31 [==============================] - 80s 3s/step - loss: 0.2152 - accuracy: 0.9123 - val_loss: 0.9309 - val_accuracy: 0.7734
# Epoch 99/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2226 - accuracy: 0.9168
# Epoch 99: val_loss did not improve from 0.37320
# 31/31 [==============================] - 80s 3s/step - loss: 0.2226 - accuracy: 0.9168 - val_loss: 0.8168 - val_accuracy: 0.7891
# Epoch 100/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2291 - accuracy: 0.9088
# Epoch 100: val_loss did not improve from 0.37320
# 31/31 [==============================] - 80s 3s/step - loss: 0.2291 - accuracy: 0.9088 - val_loss: 0.7647 - val_accuracy: 0.8125

# %%
# evaluation
# load testing set
test_metadata_filename = "test.csv"
df_test = pd.read_csv(test_metadata_filename)
n_testing_samples = len(df_test)
print("Number of testing samples:", n_testing_samples)
test_ds = tf.data.Dataset.from_tensor_slices((df_test["filepath"], df_test["label"]))

def prepare_for_testing(ds, cache=True, shuffle_buffer_size=1000):
  if cache:
    if isinstance(cache, str):
      ds = ds.cache(cache)
    else:
      ds = ds.cache()
  ds = ds.shuffle(buffer_size=shuffle_buffer_size)
  return ds

test_ds = test_ds.map(process_path)
test_ds = prepare_for_testing(test_ds, cache="test-cached-data")
# Out:
# Number of testing samples: 600

# %%
# convert testing set to numpy array to fit in memory (don't do that when testing
# set is too large)
y_test = np.zeros((n_testing_samples,))
X_test = np.zeros((n_testing_samples, 299, 299, 3))
for i, (img, label) in enumerate(test_ds.take(n_testing_samples)):
  # print(img.shape, label.shape)
  X_test[i] = img
  y_test[i] = label.numpy()

print("y_test.shape:", y_test.shape)
# Out:
# y_test.shape: (600,)

# %%
# load the weights with the least loss
m.load_weights("benign-vs-malignant_64_rmsprop_0.373.h5")

# %%
print("Evaluating the model...")
loss, accuracy = m.evaluate(X_test, y_test, verbose=0)
print("Loss:", loss, "  Accuracy:", accuracy)
# Out:
# Evaluating the model...
# Loss: 0.4565918445587158   Accuracy: 0.7950000166893005

# %%
def get_predictions(threshold=None):
  """
  Returns predictions for binary classification given `threshold`
  For instance, if threshold is 0.3, then it'll output 1 (malignant) for that sample if
  the probability of 1 is 30% or more (instead of 50%)
  """
  y_pred = m.predict(X_test)
  if not threshold:
    threshold = 0.5
  result = np.zeros((n_testing_samples,))
  for i in range(n_testing_samples):
    # test melanoma probability
    if y_pred[i][0] >= threshold:
      result[i] = 1
    # else, it's 0 (benign)
  return result

threshold = 0.23
# get predictions with 23% threshold
# which means if the model is 23% sure or more that is malignant,
# it's assigned as malignant, otherwise it's benign
y_pred = get_predictions(threshold)
# Out:
# 19/19 [==============================] - 38s 2s/step

# %%
def plot_confusion_matrix(y_test, y_pred):
  cmn = confusion_matrix(y_test, y_pred)
  # Normalise
  cmn = cmn.astype('float') / cmn.sum(axis=1)[:, np.newaxis]
  # print it
  print(cmn)
  fig, ax = plt.subplots(figsize=(10,10))
  sns.heatmap(cmn, annot=True, fmt='.2f', 
              xticklabels=[f"pred_{c}" for c in class_names], 
              yticklabels=[f"true_{c}" for c in class_names],
              cmap="Blues"
              )
  plt.ylabel('Actual')
  plt.xlabel('Predicted')
  # plot the resulting confusion matrix
  plt.show()

plot_confusion_matrix(y_test, y_pred)
# Out:
# [[0.98757764 0.01242236]
#  [0.96581197 0.03418803]]

# %%
sensitivity = sensitivity_score(y_test, y_pred)
specificity = specificity_score(y_test, y_pred)

print("Melanoma Sensitivity:", sensitivity)
print("Melanoma Specificity:", specificity)
# Out:
# Melanoma Sensitivity: 0.03418803418803419
# Melanoma Specificity: 0.9875776397515528

# %%
def plot_roc_auc(y_true, y_pred):
    """
    This function plots the ROC curves and provides the scores.
    """
    # prepare for figure
    plt.figure()
    fpr, tpr, _ = roc_curve(y_true, y_pred)
    # obtain ROC AUC
    roc_auc = auc(fpr, tpr)
    # print score
    print(f"ROC AUC: {roc_auc:.3f}")
    # plot ROC curve
    plt.plot(fpr, tpr, color="blue", lw=2,
                label='ROC curve (area = {f:.2f})'.format(d=1, f=roc_auc))
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC curves')
    plt.legend(loc="lower right")
    plt.show()

plot_roc_auc(y_test, y_pred)
# Out:
# ROC AUC: 0.511
